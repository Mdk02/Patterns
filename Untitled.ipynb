# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_rows = 67
pd.options.display.max_columns = 67

# %% [markdown]
# # 1.1 Парсинг данных

# %% [markdown]
# # Считывание данных в датафрейм

# %%
df = pd.read_csv('covid.csv')

# %%
df.head(8)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
# 5                 NaN           NaN         NaN                  NaN
# 6               0.714           NaN         NaN                  NaN
# 7               0.000           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.126                  0.126
# 1                    0.126                  0.000
# 2                    0.126                  0.000
# 3                    0.126                  0.000
# 4                    0.126                  0.000
# 5                    0.126                  0.000
# 6                    0.126                  0.000
# 7                    0.126                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# 5                             NaN                       NaN
# 6                           0.018                       NaN
# 7                           0.000                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
# 5                     NaN                              NaN                NaN
# 6                     NaN                              NaN                NaN
# 7                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
# 5           NaN                       NaN            NaN
# 6           NaN                       NaN            NaN
# 7           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# 5                                NaN                     NaN
# 6                                NaN                     NaN
# 7                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                 NaN          NaN        NaN
# 1                                 NaN          NaN        NaN
# 2                                 NaN          NaN        NaN
# 3                                 NaN          NaN        NaN
# 4                                 NaN          NaN        NaN
# 5                                 NaN          NaN        NaN
# 6                                 NaN          NaN        NaN
# 7                                 NaN          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
# 5                       NaN                     NaN                 NaN
# 6                       NaN                     NaN                 NaN
# 7                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
# 5                              NaN            NaN             NaN         NaN
# 6                              NaN            NaN             NaN         NaN
# 7                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
# 5                 NaN                NaN                      NaN
# 6                 NaN                NaN                      NaN
# 7                 NaN                NaN                      NaN
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0             NaN               NaN                        NaN
# 1             NaN               NaN                        NaN
# 2             NaN               NaN                        NaN
# 3             NaN               NaN                        NaN
# 4             NaN               NaN                        NaN
# 5             NaN               NaN                        NaN
# 6             NaN               NaN                        NaN
# 7             NaN               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5                                  NaN                         NaN
# 6                                  NaN                         NaN
# 7                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# 5                                    NaN                             NaN
# 6                                    NaN                             NaN
# 7                                    NaN                             NaN
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  population  \
# 0                                         NaN              8.33  39835428.0
# 1                                         NaN              8.33  39835428.0
# 2                                         NaN              8.33  39835428.0
# 3                                         NaN              8.33  39835428.0
# 4                                         NaN              8.33  39835428.0
# 5                                         NaN              8.33  39835428.0
# 6                                         NaN             27.78  39835428.0
# 7                                         NaN             27.78  39835428.0
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
# 5              54.422        18.6          2.581          1.337
# 6              54.422        18.6          2.581          1.337
# 7              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
# 5        1803.987              NaN                597.029
# 6        1803.987              NaN                597.029
# 7        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
# 5                 9.59             NaN           NaN                  37.746
# 6                 9.59             NaN           NaN                  37.746
# 7                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
# 5                         0.5            64.83                    0.511
# 6                         0.5            64.83                    0.511
# 7                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN

# %% [markdown]
# # 1.2 Предобработка данных и выделение значимых атрибутов

# %%
df2 = df.copy(deep=True)

# %%
df2
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 169934      ZWE    Africa     Zimbabwe  2022-03-16     243650.0      741.0
# 169935      ZWE    Africa     Zimbabwe  2022-03-17     243650.0        0.0
# 169936      ZWE    Africa     Zimbabwe  2022-03-18     244012.0      362.0
# 169937      ZWE    Africa     Zimbabwe  2022-03-19     244452.0      440.0
# 169938      ZWE    Africa     Zimbabwe  2022-03-20     244452.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 169934             472.429        5418.0         2.0                2.571
# 169935             300.286        5418.0         0.0                1.429
# 169936             352.000        5420.0         2.0                1.714
# 169937             340.429        5426.0         6.0                2.000
# 169938                 NaN        5426.0         0.0                1.714
#
#         total_cases_per_million  new_cases_per_million  \
# 0                         0.126                  0.126
# 1                         0.126                  0.000
# 2                         0.126                  0.000
# 3                         0.126                  0.000
# 4                         0.126                  0.000
# ...                         ...                    ...
# 169934                16144.132                 49.098
# 169935                16144.132                  0.000
# 169936                16168.118                 23.986
# 169937                16197.272                 29.154
# 169938                16197.272                    NaN
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 169934                          31.303                   358.994
# 169935                          19.897                   358.994
# 169936                          23.323                   359.127
# 169937                          22.557                   359.524
# 169938                             NaN                   359.524
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
# ...                        ...                              ...
# 169934                   0.133                            0.170
# 169935                   0.000                            0.095
# 169936                   0.133                            0.114
# 169937                   0.398                            0.133
# 169938                   0.000                            0.114
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 0                     NaN           NaN                       NaN
# 1                     NaN           NaN                       NaN
# 2                     NaN           NaN                       NaN
# 3                     NaN           NaN                       NaN
# 4                     NaN           NaN                       NaN
# ...                   ...           ...                       ...
# 169934               0.90           NaN                       NaN
# 169935               0.87           NaN                       NaN
# 169936                NaN           NaN                       NaN
# 169937                NaN           NaN                       NaN
# 169938                NaN           NaN                       NaN
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 0                 NaN                        NaN                    NaN
# 1                 NaN                        NaN                    NaN
# 2                 NaN                        NaN                    NaN
# 3                 NaN                        NaN                    NaN
# 4                 NaN                        NaN                    NaN
# ...               ...                        ...                    ...
# 169934            NaN                        NaN                    NaN
# 169935            NaN                        NaN                    NaN
# 169936            NaN                        NaN                    NaN
# 169937            NaN                        NaN                    NaN
# 169938            NaN                        NaN                    NaN
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                                     NaN                     NaN
# 3                                     NaN                     NaN
# 4                                     NaN                     NaN
# ...                                   ...                     ...
# 169934                                NaN                     NaN
# 169935                                NaN                     NaN
# 169936                                NaN                     NaN
# 169937                                NaN                     NaN
# 169938                                NaN                     NaN
#
#         weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                      NaN          NaN        NaN
# 1                                      NaN          NaN        NaN
# 2                                      NaN          NaN        NaN
# 3                                      NaN          NaN        NaN
# 4                                      NaN          NaN        NaN
# ...                                    ...          ...        ...
# 169934                                 NaN          NaN        NaN
# 169935                                 NaN          NaN        NaN
# 169936                                 NaN          NaN        NaN
# 169937                                 NaN          NaN        NaN
# 169938                                 NaN          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                            NaN                     NaN                 NaN
# 1                            NaN                     NaN                 NaN
# 2                            NaN                     NaN                 NaN
# 3                            NaN                     NaN                 NaN
# 4                            NaN                     NaN                 NaN
# ...                          ...                     ...                 ...
# 169934                       NaN                     NaN                 NaN
# 169935                       NaN                     NaN                 NaN
# 169936                       NaN                     NaN                 NaN
# 169937                       NaN                     NaN                 NaN
# 169938                       NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 0                                   NaN            NaN             NaN
# 1                                   NaN            NaN             NaN
# 2                                   NaN            NaN             NaN
# 3                                   NaN            NaN             NaN
# 4                                   NaN            NaN             NaN
# ...                                 ...            ...             ...
# 169934                              NaN            NaN             NaN
# 169935                              NaN            NaN             NaN
# 169936                              NaN            NaN             NaN
# 169937                              NaN            NaN             NaN
# 169938                              NaN            NaN             NaN
#
#        tests_units  total_vaccinations  people_vaccinated  \
# 0              NaN                 NaN                NaN
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
# ...            ...                 ...                ...
# 169934         NaN           8187283.0          4410552.0
# 169935         NaN           8194373.0          4413298.0
# 169936         NaN           8204586.0          4416878.0
# 169937         NaN           8207722.0          4418032.0
# 169938         NaN           8210637.0          4418956.0
#
#         people_fully_vaccinated  total_boosters  new_vaccinations  \
# 0                           NaN             NaN               NaN
# 1                           NaN             NaN               NaN
# 2                           NaN             NaN               NaN
# 3                           NaN             NaN               NaN
# 4                           NaN             NaN               NaN
# ...                         ...             ...               ...
# 169934                3438471.0        338260.0           13745.0
# 169935                3440370.0        340705.0            7090.0
# 169936                3443003.0        344705.0           10213.0
# 169937                3443906.0        345784.0            3136.0
# 169938                3444793.0        346888.0            2915.0
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ...                           ...                             ...
# 169934                    31980.0                           54.25
# 169935                    31672.0                           54.30
# 169936                    31243.0                           54.36
# 169937                    30865.0                           54.38
# 169938                    30641.0                           54.40
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ...                               ...                                  ...
# 169934                          29.22                                22.78
# 169935                          29.24                                22.80
# 169936                          29.27                                22.81
# 169937                          29.27                                22.82
# 169938                          29.28                                22.83
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# ...                            ...                                    ...
# 169934                        2.24                                 2119.0
# 169935                        2.26                                 2099.0
# 169936                        2.28                                 2070.0
# 169937                        2.29                                 2045.0
# 169938                        2.30                                 2030.0
#
#         new_people_vaccinated_smoothed  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 169934                          3395.0
# 169935                          3314.0
# 169936                          3203.0
# 169937                          3046.0
# 169938                          2961.0
#
#         new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 0                                              NaN              8.33
# 1                                              NaN              8.33
# 2                                              NaN              8.33
# 3                                              NaN              8.33
# 4                                              NaN              8.33
# ...                                            ...               ...
# 169934                                       0.022               NaN
# 169935                                       0.022               NaN
# 169936                                       0.021               NaN
# 169937                                       0.020               NaN
# 169938                                       0.020               NaN
#
#         population  population_density  median_age  aged_65_older  \
# 0       39835428.0              54.422        18.6          2.581
# 1       39835428.0              54.422        18.6          2.581
# 2       39835428.0              54.422        18.6          2.581
# 3       39835428.0              54.422        18.6          2.581
# 4       39835428.0              54.422        18.6          2.581
# ...            ...                 ...         ...            ...
# 169934  15092171.0              42.729        19.6          2.822
# 169935  15092171.0              42.729        19.6          2.822
# 169936  15092171.0              42.729        19.6          2.822
# 169937  15092171.0              42.729        19.6          2.822
# 169938  15092171.0              42.729        19.6          2.822
#
#         aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0               1.337        1803.987              NaN                597.029
# 1               1.337        1803.987              NaN                597.029
# 2               1.337        1803.987              NaN                597.029
# 3               1.337        1803.987              NaN                597.029
# 4               1.337        1803.987              NaN                597.029
# ...               ...             ...              ...                    ...
# 169934          1.882        1899.775             21.4                307.846
# 169935          1.882        1899.775             21.4                307.846
# 169936          1.882        1899.775             21.4                307.846
# 169937          1.882        1899.775             21.4                307.846
# 169938          1.882        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 0                      9.59             NaN           NaN
# 1                      9.59             NaN           NaN
# 2                      9.59             NaN           NaN
# 3                      9.59             NaN           NaN
# 4                      9.59             NaN           NaN
# ...                     ...             ...           ...
# 169934                 1.82             1.6          30.7
# 169935                 1.82             1.6          30.7
# 169936                 1.82             1.6          30.7
# 169937                 1.82             1.6          30.7
# 169938                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       37.746                         0.5            64.83
# 1                       37.746                         0.5            64.83
# 2                       37.746                         0.5            64.83
# 3                       37.746                         0.5            64.83
# 4                       37.746                         0.5            64.83
# ...                        ...                         ...              ...
# 169934                  36.791                         1.7            61.49
# 169935                  36.791                         1.7            61.49
# 169936                  36.791                         1.7            61.49
# 169937                  36.791                         1.7            61.49
# 169938                  36.791                         1.7            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 0                         0.511                                   NaN
# 1                         0.511                                   NaN
# 2                         0.511                                   NaN
# 3                         0.511                                   NaN
# 4                         0.511                                   NaN
# ...                         ...                                   ...
# 169934                    0.571                                   NaN
# 169935                    0.571                                   NaN
# 169936                    0.571                                   NaN
# 169937                    0.571                                   NaN
# 169938                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 169934                          NaN               NaN
# 169935                          NaN               NaN
# 169936                          NaN               NaN
# 169937                          NaN               NaN
# 169938                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 169934                                      NaN
# 169935                                      NaN
# 169936                                      NaN
# 169937                                      NaN
# 169938                                      NaN
#
# [169939 rows x 67 columns]

# %%
df2.shape
# Out:
# (169939, 67)

# %%
df2.isna().sum()
# Out:
# iso_code                                           0
# continent                                      10151
# location                                           0
# date                                               0
# total_cases                                     3226
# new_cases                                       3420
# new_cases_smoothed                              5419
# total_deaths                                   21194
# new_deaths                                     21171
# new_deaths_smoothed                            23296
# total_cases_per_million                         3999
# new_cases_per_million                           4193
# new_cases_smoothed_per_million                  6186
# total_deaths_per_million                       21954
# new_deaths_per_million                         21931
# new_deaths_smoothed_per_million                24050
# reproduction_rate                              41264
# icu_patients                                  146182
# icu_patients_per_million                      146182
# hosp_patients                                 144826
# hosp_patients_per_million                     144826
# weekly_icu_admissions                         164347
# weekly_icu_admissions_per_million             164347
# weekly_hosp_admissions                        158778
# weekly_hosp_admissions_per_million            158778
# total_tests                                    99916
# new_tests                                     102098
# total_tests_per_thousand                       99916
# new_tests_per_thousand                        102098
# new_tests_smoothed                             84174
# new_tests_smoothed_per_thousand                84174
# positive_rate                                  90234
# tests_per_case                                 90822
# tests_units                                    81750
# total_vaccinations                            123552
# people_vaccinated                             125806
# people_fully_vaccinated                       128503
# total_boosters                                151309
# new_vaccinations                              131654
# new_vaccinations_smoothed                      82083
# total_vaccinations_per_hundred                123552
# people_vaccinated_per_hundred                 125806
# people_fully_vaccinated_per_hundred           128503
# total_boosters_per_hundred                    151309
# new_vaccinations_smoothed_per_million          82083
# new_people_vaccinated_smoothed                 82882
# new_people_vaccinated_smoothed_per_hundred     82882
# stringency_index                               37311
# population                                      1090
# population_density                             18894
# median_age                                     29258
# aged_65_older                                  30780
# aged_70_older                                  30012
# gdp_per_capita                                 28513
# extreme_poverty                                76854
# cardiovasc_death_rate                          30326
# diabetes_prevalence                            22962
# female_smokers                                 61663
# male_smokers                                   63148
# handwashing_facilities                         99943
# hospital_beds_per_thousand                     43682
# life_expectancy                                11282
# human_development_index                        30849
# excess_mortality_cumulative_absolute          164127
# excess_mortality_cumulative                   164127
# excess_mortality                              164127
# excess_mortality_cumulative_per_million       164127
# dtype: int64

# %% [markdown]
# ## Удаление пустых значений континента

# %%
df2.dropna(subset=['continent'], inplace=True)

# %% [markdown]
# ### Удаление столбцa iso_code

# %%
df2.drop(['iso_code'],axis=1, inplace=True)

# %% [markdown]
# ### Преобразование признаков в числа

# %%
# Преобразование названия страны в код
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2['Code_Location'] = le.fit_transform(df2['location'])

# %%
# Преобразование даты в число с помощью toordinal
df2['date'] = pd.to_datetime(df2['date'])
df2['dateAsInt'] = df2['date'].apply(lambda x:x.toordinal())

# %%
# Преобразование континента страны в код
le1 = LabelEncoder()
df2['Code_Continent'] = le1.fit_transform(df2['continent'])

# %% [markdown]
# ### Удаление признаков, имеющих больше 50% пропуска

# %%
for col in df2.columns:
    if df2[col].isna().sum() > df2.shape[0] / 2:
        df2.drop(columns=[col], inplace=True)

# %%
# Сохранение
df3 = df2.copy(deep=True)

# %%
# Корреляция между данными по отношению к new_cases                                   
corr = df2.corr()
corr.iloc[1]
# Out:
# total_cases                       0.595648
# new_cases                         1.000000
# new_cases_smoothed                0.943050
# total_deaths                      0.482796
# new_deaths                        0.585495
# new_deaths_smoothed               0.560129
# total_cases_per_million           0.178186
# new_cases_per_million             0.221540
# new_cases_smoothed_per_million    0.230821
# total_deaths_per_million          0.138135
# new_tests_smoothed                0.470578
# new_vaccinations_smoothed         0.136309
# new_people_vaccinated_smoothed    0.184249
# population                        0.224214
# median_age                        0.121792
# aged_65_older                     0.126806
# aged_70_older                     0.130891
# human_development_index           0.123734
# dateAsInt                         0.108313
# Code_Location                     0.051797
# Code_Continent                    0.060476
# level                             0.266380
# Name: new_cases, dtype: float64

# %%
# Поиск признаков с корреляцией больше 0.1
data = pd.DataFrame(corr.iloc[1])
data = data.reset_index()
selected_cols = data[data['new_cases'] > 0.1]['index']

# %%
selected_cols
# Out:
# 0                        total_cases
# 1                          new_cases
# 2                 new_cases_smoothed
# 3                       total_deaths
# 4                         new_deaths
# 5                new_deaths_smoothed
# 6            total_cases_per_million
# 7              new_cases_per_million
# 8     new_cases_smoothed_per_million
# 9           total_deaths_per_million
# 10                new_tests_smoothed
# 11         new_vaccinations_smoothed
# 12    new_people_vaccinated_smoothed
# 13                        population
# 14                        median_age
# 15                     aged_65_older
# 16                     aged_70_older
# 17           human_development_index
# 18                         dateAsInt
# 21                             level
# Name: index, dtype: object

# %%
#l = pd.Series(['Code_Location', 'Code_Continent', 'location', 'continent', 'date'])
#selected_cols = selected_cols.append(l, ignore_index=True)

# %%
df2 = df2[selected_cols]

# %%
df2
# Out:
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0               5.0        0.0               0.714           2.0         0.0
# 1               5.0        0.0               0.000           2.0         0.0
# 2               5.0        0.0               0.000           2.0         0.0
# 3               5.0        0.0               0.000           2.0         0.0
# 4               5.0        0.0               0.000           2.0         0.0
# ...             ...        ...                 ...           ...         ...
# 154442     242909.0        0.0             366.571        5416.0         0.0
# 154443     243650.0      741.0             472.429        5418.0         2.0
# 154444     243650.0        0.0             300.286        5418.0         0.0
# 154445     244012.0      362.0             352.000        5420.0         2.0
# 154446     244452.0      440.0             340.429        5426.0         6.0
#
#         new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 0                     0.571                    0.126                  0.000
# 1                     0.571                    0.126                  0.000
# 2                     0.571                    0.126                  0.000
# 3                     0.571                    0.126                  0.000
# 4                     0.571                    0.126                  0.000
# ...                     ...                      ...                    ...
# 154442                2.286                16095.034                  0.000
# 154443                2.571                16144.132                 49.098
# 154444                1.429                16144.132                  0.000
# 154445                1.714                16168.118                 23.986
# 154446                2.000                16197.272                 29.154
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                                0.018                     0.050
# 1                                0.000                     0.050
# 2                                0.000                     0.050
# 3                                0.000                     0.050
# 4                                0.000                     0.050
# ...                                ...                       ...
# 154442                          24.289                   358.862
# 154443                          31.303                   358.994
# 154444                          19.897                   358.994
# 154445                          23.323                   359.127
# 154446                          22.557                   359.524
#
#         new_tests_smoothed  new_vaccinations_smoothed  \
# 0                   1301.0                     1367.0
# 1                   1301.0                     1367.0
# 2                   1301.0                     1367.0
# 3                   1301.0                     1367.0
# 4                   1301.0                     1367.0
# ...                    ...                        ...
# 154442              4649.0                    31952.0
# 154443              4649.0                    31980.0
# 154444              4649.0                    31672.0
# 154445              4649.0                    31243.0
# 154446              4649.0                    30865.0
#
#         new_people_vaccinated_smoothed  population  median_age  aged_65_older  \
# 0                               1367.0  39835428.0        18.6          2.581
# 1                               1367.0  39835428.0        18.6          2.581
# 2                               1367.0  39835428.0        18.6          2.581
# 3                               1367.0  39835428.0        18.6          2.581
# 4                               1367.0  39835428.0        18.6          2.581
# ...                                ...         ...         ...            ...
# 154442                          3337.0  15092171.0        19.6          2.822
# 154443                          3395.0  15092171.0        19.6          2.822
# 154444                          3314.0  15092171.0        19.6          2.822
# 154445                          3203.0  15092171.0        19.6          2.822
# 154446                          3046.0  15092171.0        19.6          2.822
#
#         aged_70_older  human_development_index  dateAsInt  level
# 0               1.337                    0.511     737485      0
# 1               1.337                    0.511     737486      0
# 2               1.337                    0.511     737487      0
# 3               1.337                    0.511     737488      0
# 4               1.337                    0.511     737489      0
# ...               ...                      ...        ...    ...
# 154442          1.882                    0.571     738229      0
# 154443          1.882                    0.571     738230      0
# 154444          1.882                    0.571     738231      0
# 154445          1.882                    0.571     738232      0
# 154446          1.882                    0.571     738233      0
#
# [154447 rows x 20 columns]

# %%
df2.isna().sum()
# Out:
# total_cases                        3219
# new_cases                          3420
# new_cases_smoothed                 5341
# total_deaths                      20981
# new_deaths                        21158
# new_deaths_smoothed               23205
# total_cases_per_million            3219
# new_cases_per_million              3420
# new_cases_smoothed_per_million     5341
# total_deaths_per_million          20981
# new_tests_smoothed                74023
# new_vaccinations_smoothed         77341
# new_people_vaccinated_smoothed    78140
# population                          317
# median_age                        19896
# aged_65_older                     21418
# aged_70_older                     20650
# human_development_index           21487
# dateAsInt                             0
# dtype: int64

# %%
df2.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  1.565690e+05  1.563680e+05       154447.000000  138807.000000
# mean   6.751994e+05  3.003033e+03         2988.162691   15110.919377
# std    3.336556e+06  1.846732e+04        17423.800588   60416.670519
# min    1.000000e+00  0.000000e+00            0.000000       1.000000
# 25%    1.868000e+03  0.000000e+00            6.143000      73.000000
# 50%    2.168500e+04  6.100000e+01           85.714000     651.000000
# 75%    2.371920e+05  7.670000e+02          837.214500    5442.500000
# max    7.973479e+07  1.382120e+06       807617.286000  971162.000000
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  138630.000000        136583.000000            156569.000000
# mean       43.678345            43.863294             31634.229316
# std       192.711766           181.992020             57174.635717
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               623.805000
# 50%         1.000000             2.000000              4815.749000
# 75%        13.000000            14.429000             40238.992000
# max      4529.000000          4190.000000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          156368.000000                   154447.000000
# mean              176.459421                      175.609169
# std               732.778674                      568.751648
# min                 0.000000                        0.000000
# 25%                 0.000000                        1.466000
# 50%                 9.980500                       17.579000
# 75%               101.175000                      122.771000
# max             51427.491000                    16052.608000
#
#        total_deaths_per_million  new_tests_smoothed  \
# count             138807.000000        8.576500e+04
# mean                 520.252206        6.074345e+04
# std                  806.242828        1.928517e+05
# min                    0.001000        0.000000e+00
# 25%                   18.299000        2.105000e+03
# 50%                  127.565000        8.515000e+03
# 75%                  731.737000        3.585900e+04
# max                 6350.981000        3.080396e+06
#
#        new_vaccinations_smoothed  new_people_vaccinated_smoothed  \
# count               8.244700e+04                    8.164800e+04
# mean                1.328677e+05                    5.394742e+04
# std                 7.826931e+05                    2.947563e+05
# min                 0.000000e+00                    0.000000e+00
# 25%                 8.760000e+02                    3.390000e+02
# 50%                 7.170000e+03                    3.040000e+03
# 75%                 4.424000e+04                    1.836300e+04
# max                 2.242429e+07                    6.785334e+06
#
#          population     median_age  aged_65_older  aged_70_older  \
# count  1.594710e+05  139892.000000  138370.000000  139138.000000
# mean   3.782045e+07      30.560642       8.760288       5.533480
# std    1.453400e+08       9.127468       6.162908       4.197302
# min    4.700000e+01      15.100000       1.144000       0.526000
# 25%    8.960050e+05      22.200000       3.507000       2.063000
# 50%    6.896655e+06      29.700000       6.378000       3.871000
# 75%    2.705363e+07      39.100000      14.178000       8.678000
# max    1.444216e+09      48.200000      27.049000      18.493000
#
#        human_development_index      dateAsInt
# count            138301.000000  159788.000000
# mean                  0.725462  737867.280259
# std                   0.150376     215.630119
# min                   0.394000  737425.000000
# 25%                   0.602000  737683.000000
# 50%                   0.744000  737873.000000
# 75%                   0.845000  738053.000000
# max                   0.957000  738234.000000

# %% [markdown]
# ### Заполнение пустых значений

# %%
# Удаление пустых значений
df2.dropna(subset=['total_cases', 'new_cases', 'new_cases_smoothed', 'total_cases_per_million', 'population'], 
          inplace=True)
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\3802876425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(subset=['total_cases', 'new_cases', 'new_cases_smoothed', 'total_cases_per_million', 'population'],

# %%
# fillna forward
df2.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\3976293484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.fillna(method='ffill', inplace=True)

# %%
# fillna back
df2.fillna(method='bfill', inplace=True)
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\3272930027.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.fillna(method='bfill', inplace=True)

# %%
df2.isna().sum()
# Out:
# total_cases                       0
# new_cases                         0
# new_cases_smoothed                0
# total_deaths                      0
# new_deaths                        0
# new_deaths_smoothed               0
# total_cases_per_million           0
# new_cases_per_million             0
# new_cases_smoothed_per_million    0
# total_deaths_per_million          0
# new_tests_smoothed                0
# new_vaccinations_smoothed         0
# new_people_vaccinated_smoothed    0
# population                        0
# median_age                        0
# aged_65_older                     0
# aged_70_older                     0
# human_development_index           0
# dateAsInt                         0
# level                             0
# dtype: int64

# %% [markdown]
# # 1.3 Описание структуры набора данных

# %% [raw]
# iso_code                                       код страны
# continent                                      континент
# location                                       страна
# date                                           дата
# total_cases                                    всего случаев
# new_cases                                      новых случаев
# new_cases_smoothed                             новых случаев за 7 дней
# total_deaths                                  всего смертей
# new_deaths                                    новых смертей
# new_deaths_smoothed                           новых смертей за 7 дней
# total_cases_per_million                        всего случаев на миллион
# new_cases_per_million                         новых случаев на миллион
# new_cases_smoothed_per_million                 новых случаев на миллион за 7 дней
# total_deaths_per_million                      всего смертей на миллион
# new_deaths_per_million                        новых смертей на миллион
# new_deaths_smoothed_per_million               новых смертей на миллион за 7 дней
# reproduction_rate                             коэффициент рождаемости
# new_tests_smoothed                            новых тестов за неделю
# new_tests_smoothed_per_thousand               новых тестов за неделю на тысячу
# tests_units                                   тестов
# new_vaccinations_smoothed                     новых вакцин за неделю
# new_vaccinations_smoothed_per_million         новых вакцин за неделю на миллион
# new_people_vaccinated_smoothed                новых вакцинированных за неделю
# new_people_vaccinated_smoothed_per_hundred    новых вакцинных за неделю на сотню
# stringency_index                              индекс строгости
# population                                      население
# population_density                             плотность населения
# median_age                                    медианный возраст
# aged_65_older                                 65-летних и старше
# aged_70_older                                 70-летних и старше
# gdp_per_capita                                ввп
# extreme_poverty                               бедность
# cardiovasc_death_rate                         смертность от сердечно-сосудистых заболеваний
# diabetes_prevalence                           с диабетом
# female_smokers                                курящих женщин
# male_smokers                                  курящих мужчин
# hospital_beds_per_thousand                    коек на тысячу
# life_expectancy                               уровень жизни
# human_development_index                       уровень развития человек
# excess_mortality_cumulative_absolute          избыточная смертность кумулятивная абсолютная
# excess_mortality_cumulative                   избыточная смертность кумулятивная
# excess_mortality                              избыточная смертность
# excess_mortality_cumulative_per_million       избыточная смертность кумулятивная на миллион

# %%
# Количество пустых значений
df.isna().sum()
# Out:
# iso_code                                           0
# continent                                      10151
# location                                           0
# date                                               0
# total_cases                                     3226
# new_cases                                       3420
# new_cases_smoothed                              5419
# total_deaths                                   21194
# new_deaths                                     21171
# new_deaths_smoothed                            23296
# total_cases_per_million                         3999
# new_cases_per_million                           4193
# new_cases_smoothed_per_million                  6186
# total_deaths_per_million                       21954
# new_deaths_per_million                         21931
# new_deaths_smoothed_per_million                24050
# reproduction_rate                              41264
# icu_patients                                  146182
# icu_patients_per_million                      146182
# hosp_patients                                 144826
# hosp_patients_per_million                     144826
# weekly_icu_admissions                         164347
# weekly_icu_admissions_per_million             164347
# weekly_hosp_admissions                        158778
# weekly_hosp_admissions_per_million            158778
# total_tests                                    99916
# new_tests                                     102098
# total_tests_per_thousand                       99916
# new_tests_per_thousand                        102098
# new_tests_smoothed                             84174
# new_tests_smoothed_per_thousand                84174
# positive_rate                                  90234
# tests_per_case                                 90822
# tests_units                                    81750
# total_vaccinations                            123552
# people_vaccinated                             125806
# people_fully_vaccinated                       128503
# total_boosters                                151309
# new_vaccinations                              131654
# new_vaccinations_smoothed                      82083
# total_vaccinations_per_hundred                123552
# people_vaccinated_per_hundred                 125806
# people_fully_vaccinated_per_hundred           128503
# total_boosters_per_hundred                    151309
# new_vaccinations_smoothed_per_million          82083
# new_people_vaccinated_smoothed                 82882
# new_people_vaccinated_smoothed_per_hundred     82882
# stringency_index                               37311
# population                                      1090
# population_density                             18894
# median_age                                     29258
# aged_65_older                                  30780
# aged_70_older                                  30012
# gdp_per_capita                                 28513
# extreme_poverty                                76854
# cardiovasc_death_rate                          30326
# diabetes_prevalence                            22962
# female_smokers                                 61663
# male_smokers                                   63148
# handwashing_facilities                         99943
# hospital_beds_per_thousand                     43682
# life_expectancy                                11282
# human_development_index                        30849
# excess_mortality_cumulative_absolute          164127
# excess_mortality_cumulative                   164127
# excess_mortality                              164127
# excess_mortality_cumulative_per_million       164127
# dtype: int64

# %%
# Распределение числовых признаков
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.667130e+05  1.665190e+05        1.645200e+05  1.487450e+05
# mean   2.659682e+06  1.200099e+04        1.199871e+04  5.892914e+04
# std    1.632399e+07  8.693407e+04        8.504487e+04  3.085341e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.101000e+03  1.000000e+00        7.000000e+00  8.200000e+01
# 50%    2.767000e+04  7.900000e+01        1.078570e+02  8.010000e+02
# 75%    3.114860e+05  1.074000e+03        1.166571e+03  7.468000e+03
# max    4.707371e+08  4.115815e+06        3.445531e+06  6.077582e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  148768.000000        146643.000000            165940.000000
# mean      169.782393           171.496063             31393.691434
# std       826.857952           812.257468             56384.089505
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               651.854000
# 50%         2.000000             2.429000              4960.013000
# 75%        19.000000            21.286000             40166.205000
# max     18021.000000         14689.286000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          165746.000000                   163753.000000
# mean              174.191013                      173.341952
# std               715.495671                      556.830273
# min                 0.000000                        0.000000
# 25%                 0.037000                        1.634000
# 50%                11.471000                       19.174000
# 75%               102.617000                      123.546000
# max             51427.491000                    16052.608000
#
#        total_deaths_per_million  new_deaths_per_million  \
# count             147985.000000           148008.000000
# mean                 523.157724                1.679808
# std                  800.938083                5.151656
# min                    0.000000                0.000000
# 25%                   19.347000                0.000000
# 50%                  134.811000                0.123000
# 75%                  740.309000                1.369000
# max                 6350.981000              453.772000
#
#        new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# count                    145889.000000      128675.000000  23757.000000
# mean                          1.681101           0.994902    891.489245
# std                           3.611448           0.368164   2667.906655
# min                           0.000000          -0.040000      0.000000
# 25%                           0.017000           0.800000     27.000000
# 50%                           0.292000           0.990000    142.000000
# 75%                           1.768000           1.180000    573.000000
# max                         144.167000           6.110000  28891.000000
#
#        icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# count              23757.000000   25113.000000               25113.000000
# mean                  23.580423    4183.590810                 168.063626
# std                   27.751179   11570.904768                 208.436226
# min                    0.000000       0.000000                   0.000000
# 25%                    3.956000     131.000000                  26.908000
# 50%                   13.161000     719.000000                  86.977000
# 75%                   34.199000    2787.000000                 229.840000
# max                  177.282000  154540.000000                1544.082000
#
#        weekly_icu_admissions  weekly_icu_admissions_per_million  \
# count            5592.000000                        5592.000000
# mean              467.674356                          15.366141
# std               624.997711                          16.423231
# min                 0.000000                           0.000000
# 25%                49.000000                           4.009000
# 50%               220.500000                          11.071500
# 75%               660.250000                          20.252750
# max              4838.000000                         221.212000
#
#        weekly_hosp_admissions  weekly_hosp_admissions_per_million  \
# count            11161.000000                        11161.000000
# mean              5957.626019                          104.432481
# std              14764.517674                          108.053977
# min                  0.000000                            0.000000
# 25%                331.000000                           24.337000
# 50%               1363.000000                           74.481000
# 75%               5238.000000                          143.092000
# max             154696.000000                          645.808000
#
#         total_tests     new_tests  total_tests_per_thousand  \
# count  7.002300e+04  6.784100e+04              70023.000000
# mean   1.782107e+07  6.874777e+04                764.416716
# std    6.578816e+07  2.163062e+05               1856.303457
# min    0.000000e+00  1.000000e+00                  0.000000
# 25%    3.920395e+05  2.500000e+03                 36.453000
# 50%    1.994656e+06  9.878000e+03                185.986000
# 75%    9.414876e+06  3.930900e+04                731.384500
# max    8.310325e+08  3.740296e+06              29975.950000
#
#        new_tests_per_thousand  new_tests_smoothed  \
# count            67841.000000        8.576500e+04
# mean                 3.256734        6.074345e+04
# std                  9.007831        1.928517e+05
# min                  0.000000        0.000000e+00
# 25%                  0.262000        2.105000e+03
# 50%                  0.950000        8.515000e+03
# 75%                  2.916000        3.585900e+04
# max                534.013000        3.080396e+06
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# count                      85765.00000   79705.000000    79117.000000
# mean                           2.91118       0.098794      181.268427
# std                            7.53956       0.111289     4177.606677
# min                            0.00000       0.000000        1.000000
# 25%                            0.23200       0.019200        7.100000
# 50%                            0.89600       0.058000       16.900000
# 75%                            2.69900       0.140200       50.100000
# max                          147.60300       0.991200   422065.600000
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.638700e+04       4.413300e+04             4.143600e+04
# mean         1.812921e+08       9.210283e+07             7.337464e+07
# std          8.121337e+08       4.132602e+08             3.442124e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          6.289220e+05       3.978260e+05             2.855230e+05
# 50%          4.996503e+06       3.063985e+06             2.422614e+06
# 75%          3.124527e+07       1.820456e+07             1.421863e+07
# max          1.100343e+10       5.039958e+09             4.497968e+09
#
#        total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# count    1.863000e+04      3.828500e+04               8.785600e+04
# mean     2.216464e+07      1.170123e+06               5.132162e+05
# std      1.035721e+08      4.347013e+06               2.774724e+06
# min      1.000000e+00      0.000000e+00               0.000000e+00
# 25%      3.630250e+03      6.160000e+03               1.012000e+03
# 50%      5.334295e+05      4.123600e+04               9.057500e+03
# 75%      4.648266e+06      2.773900e+05               6.483600e+04
# max      1.465587e+09      5.485842e+07               4.353539e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    46387.000000                   44133.000000
# mean                        75.109262                      38.626901
# std                         65.899830                      29.097021
# min                          0.000000                       0.000000
# 25%                         12.830000                       9.100000
# 50%                         61.010000                      37.600000
# 75%                        126.640000                      65.340000
# max                        340.670000                     124.740000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         41436.000000                18630.000000
# mean                             33.376340                   13.519999
# std                              27.986226                   18.114666
# min                               0.000000                    0.000000
# 25%                               5.460000                    0.020000
# 50%                              28.380000                    3.850000
# 75%                              59.160000                   23.297500
# max                             121.990000                   93.930000
#
#        new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# count                           87856.000000                    8.705700e+04
# mean                             3262.137896                    2.066615e+05
# std                              3877.548788                    1.152224e+06
# min                                 0.000000                    0.000000e+00
# 25%                               661.000000                    4.100000e+02
# 50%                              2124.000000                    3.783000e+03
# 75%                              4674.000000                    2.614100e+04
# max                            117497.000000                    2.139666e+07
#
#        new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# count                                87057.000000      132628.00000
# mean                                     0.145529          54.37811
# std                                      0.242400          20.47328
# min                                      0.000000           0.00000
# 25%                                      0.023000          40.74000
# 50%                                      0.070000          54.63000
# 75%                                      0.186000          70.37000
# max                                     11.750000         100.00000
#
#          population  population_density     median_age  aged_65_older  \
# count  1.688490e+05       151045.000000  140681.000000  139159.000000
# mean   1.471081e+08          464.058914      30.562546       8.759923
# std    7.047042e+08         2142.833362       9.101872       6.145414
# min    4.700000e+01            0.137000      15.100000       1.144000
# 25%    1.172369e+06           36.253000      22.200000       3.507000
# 50%    8.478242e+06           85.129000      29.900000       6.614000
# 75%    3.393361e+07          212.865000      39.100000      14.178000
# max    7.874966e+09        20546.766000      48.200000      27.049000
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count  139927.000000   141426.000000     93085.000000          139613.000000
# mean        5.532474    19634.008193        13.586807             260.292173
# std         4.185473    20639.753016        20.024808             119.894280
# min         0.526000      661.240000         0.100000              79.370000
# 25%         2.063000     4449.898000         0.600000             168.711000
# 50%         3.915000    12951.839000         2.200000             243.811000
# 75%         8.678000    27936.896000        21.200000             329.942000
# max        18.493000   116935.600000        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers   male_smokers  \
# count        146977.000000   108276.000000  106791.000000
# mean              8.217380       10.638762      32.781348
# std               4.504439       10.573555      13.523319
# min               0.990000        0.100000       7.700000
# 25%               5.310000        1.900000      21.600000
# 50%               7.200000        6.300000      31.400000
# 75%              10.430000       19.300000      41.300000
# max              30.530000       44.000000      78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            69996.000000               126257.000000    158657.000000
# mean                50.784230                    3.028247        73.571272
# std                 31.813101                    2.449577         7.490320
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        69.500000
# 50%                 49.839000                    2.400000        75.050000
# 75%                 83.241000                    4.000000        78.930000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            139090.000000                          5.812000e+03
# mean                  0.725528                          3.840378e+04
# std                   0.149951                          1.064601e+05
# min                   0.394000                         -3.772610e+04
# 25%                   0.602000                         -5.910000e+01
# 50%                   0.743000                          3.508250e+03
# 75%                   0.845000                          2.614535e+04
# max                   0.957000                          1.111864e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  5812.000000       5812.000000
# mean                      9.510372         15.995807
# std                      16.445978         29.970960
# min                     -28.450000        -95.920000
# 25%                      -0.620000         -0.740000
# 50%                       6.185000          7.330000
# 75%                      14.612500         23.107500
# max                     111.010000        375.000000
#
#        excess_mortality_cumulative_per_million
# count                              5812.000000
# mean                                995.966564
# std                                1445.335337
# min                               -1826.595723
# 25%                                 -26.709757
# 50%                                 481.813402
# 75%                                1675.686372
# max                                9339.469641

# %% [markdown]
# ## Просмотр распределения данных с помощью гистограммы

# %%
for col in df2.columns:
    plt.figure(figsize=(8,6))
    plt.hist(df2[col], bins=100);
    plt.xlabel(col)
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\89455301.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(8,6))

# %% [markdown]
# # 1.4 Формирование дополнительных атрибутов

# %% [markdown]
# # 1.5 Кластеризация набора данных

# %% [markdown]
# ## Будут использоваться такие модели кластеризации как Kmeans, Birch и GaussianMixture, так как позволяют работать с большими объемами данных и выбирать количество кластеров
#
# ### kmeans -
#
# #### Он разбивает множество элементов векторного пространства на заранее известное число кластеров k. Основная идея заключается в том, что на каждой итерации перевычисляется центр масс для каждого кластера, полученного на предыдущем шаге, затем векторы разбиваются на кластеры вновь в соответствии с тем, какой из новых центров оказался ближе по выбранной метрике
#
# ### MiniBatchKMeans -
#
# #### это вариант алгоритма KMeans, который использует мини-пакеты длясокращения времени вычислений, но при этом пытается оптимизировать ту же целевуюфункцию.
#
# ### GaussianMixture -
#
# #### Модель смеси Гаусса (GMM) пытается найти смесь многомерных гауссовских распределений вероятностей, которые лучше всего моделируют любой входной набор данных. В простейшем случае ГММ могут использоваться для поиска кластеров таким же образом, как k-средние

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn import metrics

# %%
# Скалирование данных
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df2)
X_scale = scaler.transform(df2)
scaled_data = pd.DataFrame(X_scale, columns=df2.columns)

# %% [markdown]
# ### KMeans

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=0)
label = kmeans.fit_predict(scaled_data)

# %%
pd.Series(label).value_counts()
# Out:
# 0    90283
# 1    62130
# 2     2034
# dtype: int64

# %% [markdown]
# ### MiniBatchKMeans

# %%
label2 = MiniBatchKMeans(n_clusters=3).fit_predict(scaled_data)

# %%
pd.Series(label2).value_counts()
# Out:
# 1    90194
# 0    62641
# 2     1612
# dtype: int64

# %% [markdown]
# ### GaussianMixture

# %%
gmm = GaussianMixture(3, covariance_type='full', random_state=0).fit(scaled_data)
labels3 = gmm.predict(scaled_data)

# %%
pd.Series(labels3).value_counts()
# Out:
# 0    67997
# 1    64068
# 2    22382
# dtype: int64

# %% [markdown]
# ### Калински-Харабаш
#
# ### Чем больше значений метрик, тем лучше расположены кластеры, следовательно далее будет использоваться kmeans

# %%
print('метрики kmeans = ' + str(metrics.calinski_harabasz_score(scaled_data, label)) + '\n' +
     'метрики Minibatch = ' + str(metrics.calinski_harabasz_score(scaled_data, label2)) + '\n' +
      'метрики GaussianMixture = ' + str(metrics.calinski_harabasz_score(scaled_data, labels3)))
# Out:
# метрики kmeans = 34655.82581457966
# метрики Minibatch = 34538.94428618004
# метрики GaussianMixture = 11031.633900995548

# %% [markdown]
# ### Индекс Дэвиса-Булдина
#
# ### Этот показатель измеряет сходство ваших кластеров, что означает, что чем ниже оценка, тем лучше разделение между вашими кластерами

# %%
from sklearn.metrics import davies_bouldin_score

# %%
print('метрики kmeans = ' + str(davies_bouldin_score(scaled_data, label)) + '\n' +
     'метрики Minibatch = ' + str(davies_bouldin_score(scaled_data, label2)) + '\n' +
      'метрики GaussianMixture = ' + str(davies_bouldin_score(scaled_data, labels3)))
# Out:
# метрики kmeans = 1.45222586704934
# метрики Minibatch = 1.4422192711983612
# метрики GaussianMixture = 3.012521364611157

# %% [markdown]
# ### Делая вывод по этим метрикам, можно сказать, что Minibatch и kmeans отработали +- одинаково хорошо. Поэтому для дальнейшей работы будет использоваться kmeans

# %% [markdown]
# ### График Kmeans

# %%
# Уменьшение размерности датафрейма до 2-х измерений для визуализации
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)

x_pca = pca.transform(scaled_data)
np.shape(x_pca)
# Out:
# (154447, 2)

# %%
# График распределения кластеров в kmeans
plt.figure(figsize=(12,8))
plt.scatter(x_pca[:,0],x_pca[:,1],c=label,cmap='rainbow', alpha=0.4)
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
# Сохранение результатов в датафрейм
df2['level'] = label
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\967353834.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['level'] = label

# %% [markdown]
# ## Просмотр того, как распределились кластеры

# %%
df2[df2['level'] == 0].describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  9.028300e+04  90283.000000        90283.000000   90283.000000
# mean   1.584161e+05    624.722805          618.021173    5610.856883
# std    5.361600e+05   2369.804347         2242.953888   26960.543372
# min    1.000000e+00      0.000000            0.000000       1.000000
# 25%    8.920000e+02      0.000000            2.714000      51.000000
# 50%    1.163500e+04     22.000000           37.571000     314.000000
# 75%    9.935200e+04    294.000000          319.286000    2349.000000
# max    1.124479e+07  64718.000000        55675.286000  516510.000000
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  90283.000000         90283.000000             90283.000000
# mean      13.407851            13.571328             13610.843381
# std       51.614868            49.827038             27753.985223
# min        0.000000             0.000000                 0.002000
# 25%        0.000000             0.000000               335.386000
# 50%        0.000000             0.714000              2295.941000
# 75%        5.000000             5.571000             12654.852500
# max     2003.000000          1277.571000            301858.703000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           90283.000000                    90283.000000
# mean               56.738643                       58.432020
# std               215.437641                      176.020774
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.665000
# 50%                 2.651000                        5.698000
# 75%                31.358500                       40.649000
# max              8620.690000                     4522.155000
#
#        total_deaths_per_million  new_tests_smoothed  \
# count              90283.000000        9.028300e+04
# mean                 265.151071        2.825304e+04
# std                  494.849411        8.706200e+04
# min                    0.001000        1.000000e+00
# 25%                   11.422000        1.165000e+03
# 50%                   61.930000        4.842000e+03
# 75%                  265.019000        1.295600e+04
# max                 5260.811000        1.088920e+06
#
#        new_vaccinations_smoothed  new_people_vaccinated_smoothed  \
# count               9.028300e+04                    9.028300e+04
# mean                5.824684e+04                    2.025274e+04
# std                 1.944881e+05                    7.479859e+04
# min                 0.000000e+00                    0.000000e+00
# 25%                 5.650000e+02                    1.330000e+02
# 50%                 3.949000e+03                    1.286000e+03
# 75%                 2.969950e+04                    9.145000e+03
# max                 4.728286e+06                    2.824092e+06
#
#          population    median_age  aged_65_older  aged_70_older  \
# count  9.028300e+04  90283.000000   90283.000000   90283.000000
# mean   3.077151e+07     24.012208       4.450764       2.603462
# std    1.036477e+08      5.305634       2.225788       1.180204
# min    8.120000e+02     15.100000       1.144000       0.526000
# 25%    1.172369e+06     19.300000       2.979000       1.745000
# 50%    9.119005e+06     23.100000       3.810000       2.242000
# 75%    2.842733e+07     28.600000       5.344000       3.182000
# max    1.444216e+09     38.700000      18.436000       6.405000
#
#        human_development_index      dateAsInt    level
# count             90283.000000   90283.000000  90283.0
# mean                  0.634167  737856.942725      0.0
# std                   0.120762     209.113241      0.0
# min                   0.394000  737453.000000      0.0
# 25%                   0.543000  737677.000000      0.0
# 50%                   0.630000  737853.000000      0.0
# 75%                   0.728000  738034.000000      0.0
# max                   0.919000  738234.000000      0.0

# %%
df2[df2['level'] == 1].describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  6.213000e+04   62130.000000        62130.000000   62130.000000
# mean   7.588710e+05    3593.988057         3585.381429   18662.489683
# std    1.823903e+06   10516.916435        10026.260204   45168.702460
# min    1.000000e+00       0.000000            0.000000       1.000000
# 25%    5.516250e+03      10.000000           20.714000     150.000000
# 50%    7.989200e+04     268.000000          344.143000    1869.000000
# 75%    6.311435e+05    2036.000000         2234.071500   15042.750000
# max    2.418993e+07  243295.000000       198524.714000  657495.000000
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  62130.000000         62130.000000             62130.000000
# mean      49.363560            49.915407             56868.001039
# std      137.665188           130.264369             75287.674493
# min        0.000000             0.000000                 0.009000
# 25%        0.000000             0.286000              2335.688500
# 50%        4.000000             5.143000             30603.997500
# 75%       29.000000            32.000000             83947.473250
# max     3351.000000          1879.571000            706541.904000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           62130.000000                    62130.000000
# mean              343.054830                      335.721704
# std              1087.330125                      824.389463
# min                 0.000000                        0.000000
# 25%                 3.244000                       10.359250
# 50%                62.243500                       84.222500
# 75%               266.972750                      294.014250
# max             51427.491000                    16052.608000
#
#        total_deaths_per_million  new_tests_smoothed  \
# count              62130.000000        6.213000e+04
# mean                 982.018536        7.096803e+04
# std                 1014.546268        1.833960e+05
# min                    0.003000        0.000000e+00
# 25%                  101.215000        3.731000e+03
# 50%                  731.414000        1.334100e+04
# 75%                 1591.017000        5.150300e+04
# max                 6350.981000        1.627907e+06
#
#        new_vaccinations_smoothed  new_people_vaccinated_smoothed  \
# count               6.213000e+04                    6.213000e+04
# mean                9.987893e+04                    2.362170e+04
# std                 4.364070e+05                    7.023335e+04
# min                 0.000000e+00                    0.000000e+00
# 25%                 8.200000e+02                    1.490000e+02
# 50%                 9.215500e+03                    2.111500e+03
# 75%                 4.272975e+04                    1.545000e+04
# max                 7.579857e+06                    2.002548e+06
#
#          population    median_age  aged_65_older  aged_70_older  \
# count  6.213000e+04  62130.000000   62130.000000   62130.000000
# mean   2.910661e+07     39.129693      14.680626       9.382268
# std    1.200362e+08      5.083037       4.743458       3.523193
# min    4.981000e+03     16.800000       2.372000       1.362000
# 25%    6.583910e+05     35.700000      10.864000       6.489000
# 50%    5.453600e+06     39.800000      14.799000       9.473000
# 75%    1.921236e+07     43.000000      18.779000      12.325000
# max    1.444216e+09     48.200000      27.049000      18.493000
#
#        human_development_index      dateAsInt    level
# count             62130.000000   62130.000000  62130.0
# mean                  0.850469  737881.449976      1.0
# std                   0.077839     218.426130      0.0
# min                   0.485000  737453.000000      1.0
# 25%                   0.783000  737695.000000      1.0
# 50%                   0.854000  737892.000000      1.0
# 75%                   0.919000  738074.000000      1.0
# max                   0.957000  738234.000000      1.0

# %%
df2[df2['level'] == 2].describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  2.034000e+03  2.034000e+03         2034.000000    2034.000000
# mean   2.134040e+07  9.208560e+04        89948.972117  360567.264012
# std    1.730998e+07  1.197736e+05       109278.144391  253749.078493
# min    9.400000e+01  0.000000e+00           10.857000    4636.000000
# 25%    8.558574e+06  2.463450e+04        27835.714000  133049.250000
# 50%    1.779664e+07  5.235250e+04        56613.785500  352106.500000
# 75%    3.298176e+07  1.158095e+05       119594.250000  561983.750000
# max    7.973479e+07  1.382120e+06       807617.286000  971162.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  2034.000000          2034.000000              2034.000000
# mean    971.719764           964.220117             72177.185203
# std     973.059896           873.354476             67649.153879
# min       0.000000             0.000000                26.972000
# 25%     266.000000           282.178750             16830.580000
# 50%     657.500000           745.714500             60470.159500
# 75%    1327.000000          1329.821250            104455.173750
# max    4529.000000          4190.000000            333037.347000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count            2034.000000                     2034.000000
# mean              524.731653                      485.989081
# std              1201.999168                      969.375407
# min                 0.000000                        0.008000
# 25%                32.102750                       33.211750
# 50%               160.170000                      176.447500
# 75%               375.051000                      358.327500
# max             22150.872000                     7893.892000
#
#        total_deaths_per_million  new_tests_smoothed  \
# count               2034.000000        2.034000e+03
# mean                1241.566840        1.032758e+06
# std                 1014.255992        6.244675e+05
# min                    3.210000        8.500000e+02
# 25%                  282.477250        5.207015e+05
# 50%                 1321.212500        1.113548e+06
# 75%                 2171.903250        1.627907e+06
# max                 3072.501000        3.080396e+06
#
#        new_vaccinations_smoothed  new_people_vaccinated_smoothed  \
# count               2.034000e+03                    2.034000e+03
# mean                2.587822e+06                    9.932796e+05
# std                 3.917324e+06                    1.458481e+06
# min                 7.000000e+01                    1.000000e+01
# 25%                 3.108412e+05                    4.589475e+04
# 50%                 9.723910e+05                    3.534310e+05
# 75%                 2.782844e+06                    1.166228e+06
# max                 2.242429e+07                    6.785334e+06
#
#          population   median_age  aged_65_older  aged_70_older  \
# count  2.034000e+03  2034.000000    2034.000000    2034.000000
# mean   6.576249e+08    35.429990      11.516175       7.173044
# std    5.662429e+08     5.119756       4.661380       3.374249
# min    3.485152e+06    28.200000       5.319000       3.053000
# 25%    2.139934e+08    29.300000       5.989000       3.414000
# 50%    3.329151e+08    38.300000      10.641000       5.929000
# 75%    1.393409e+09    38.700000      15.413000       9.732000
# max    1.444216e+09    47.900000      23.021000      16.240000
#
#        human_development_index      dateAsInt   level
# count              2034.000000    2034.000000  2034.0
# mean                  0.799218  737998.754179     2.0
# std                   0.112112     171.841699     0.0
# min                   0.645000  737503.000000     2.0
# 25%                   0.704000  737892.000000     2.0
# 50%                   0.765000  738021.000000     2.0
# 75%                   0.926000  738148.000000     2.0
# max                   0.947000  738234.000000     2.0

# %% [markdown]
# ## 0- Безопасно
# ## 1 - Средне
# ## 2 - Опасно

# %%
l = ['Code_Location', 'Code_Continent', 'location', 'continent', 'date']
for i in l:
    df2[i] = df3[i]
# Out:
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\1446445859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[i] = df3[i]
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\1446445859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[i] = df3[i]
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\1446445859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[i] = df3[i]
# C:\Users\1\AppData\Local\Temp\ipykernel_11176\1446445859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[i] = df3[i]

# %%
df2.head()
# Out:
#     total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 6           5.0        0.0               0.714           2.0         0.0
# 7           5.0        0.0               0.000           2.0         0.0
# 8           5.0        0.0               0.000           2.0         0.0
# 9           5.0        0.0               0.000           2.0         0.0
# 10          5.0        0.0               0.000           2.0         0.0
#
#     new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 6                 0.571                    0.126                    0.0
# 7                 0.571                    0.126                    0.0
# 8                 0.571                    0.126                    0.0
# 9                 0.571                    0.126                    0.0
# 10                0.571                    0.126                    0.0
#
#     new_cases_smoothed_per_million  total_deaths_per_million  \
# 6                            0.018                      0.05
# 7                            0.000                      0.05
# 8                            0.000                      0.05
# 9                            0.000                      0.05
# 10                           0.000                      0.05
#
#     new_tests_smoothed  new_vaccinations_smoothed  \
# 6               1301.0                     1367.0
# 7               1301.0                     1367.0
# 8               1301.0                     1367.0
# 9               1301.0                     1367.0
# 10              1301.0                     1367.0
#
#     new_people_vaccinated_smoothed  population  median_age  aged_65_older  \
# 6                           1367.0  39835428.0        18.6          2.581
# 7                           1367.0  39835428.0        18.6          2.581
# 8                           1367.0  39835428.0        18.6          2.581
# 9                           1367.0  39835428.0        18.6          2.581
# 10                          1367.0  39835428.0        18.6          2.581
#
#     aged_70_older  human_development_index  dateAsInt  Code_Location  \
# 6           1.337                    0.511     737485              0
# 7           1.337                    0.511     737486              0
# 8           1.337                    0.511     737487              0
# 9           1.337                    0.511     737488              0
# 10          1.337                    0.511     737489              0
#
#     Code_Continent  level     location continent       date
# 6                1      0  Afghanistan      Asia 2020-03-01
# 7                1      0  Afghanistan      Asia 2020-03-02
# 8                1      0  Afghanistan      Asia 2020-03-03
# 9                1      0  Afghanistan      Asia 2020-03-04
# 10               1      0  Afghanistan      Asia 2020-03-05

# %%
df2.to_csv('df.csv', index=False)

# %% [markdown]
# # 1.6 Подготовка отчета

# %% [markdown]
# ## 1.1 были получены данные

# %% [markdown]
# ## 1.2 данные были обработаны

# %% [markdown]
# ## 1.3 просмотр количества пустых значений, распределения признаков и значения признаков

# %% [markdown]
# ## 1.4

# %% [markdown]
# ## 1.5 данные были поделены на классы опасности с помощью кластеризации
