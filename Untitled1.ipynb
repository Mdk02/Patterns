# %% [markdown]
# # Импорт библиотек

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# # Считывание данных

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0               5.0        0.0               0.714           2.0         0.0
# 1               5.0        0.0               0.000           2.0         0.0
# 2               5.0        0.0               0.000           2.0         0.0
# 3               5.0        0.0               0.000           2.0         0.0
# 4               5.0        0.0               0.000           2.0         0.0
# ...             ...        ...                 ...           ...         ...
# 154442     242909.0        0.0             366.571        5416.0         0.0
# 154443     243650.0      741.0             472.429        5418.0         2.0
# 154444     243650.0        0.0             300.286        5418.0         0.0
# 154445     244012.0      362.0             352.000        5420.0         2.0
# 154446     244452.0      440.0             340.429        5426.0         6.0
#
# ...

# %% [markdown]
# # 2.1 Разбиение набора данных

# %% [markdown]
# ### Обычно данные разбиваются в соотношениях 66/33, 70/30 или 80/20 в зависимости от объема данных, как рекомендуется в множестве пособий, я же буду использовать 70/30 как нечто среднее и оптимальное для большинства случаев

# %%
X = df.drop(['level', 'location', 'date', 'continent'], axis=1)
y = df['level']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# # 2.2 Визуализация зависимостей данных

# %% [markdown]
# ## Строительство сразу нескольких графиков для уровня и какого-то другого признака

# %% [markdown]
# ## Используется scatter, так как можно увидеть зависимость

# %%
for i in df.columns:
    plt.figure(figsize=(12,8))
    plt.scatter(df['level'], df[i]);
    plt.xlabel('level')
    plt.ylabel(i)

# %% [markdown]
# # 2.3 Классификация исходных компетенций

# %% [markdown]
# ## DecisionTreeClassifier -
#
# ### Дерево решений - это древовидная структура, подобная блок-схеме, в которой внутренний узел представляет функцию (или атрибут), ветвь представляет правило принятия решений, а каждый конечный узел представляет результат. Самый верхний узел в дереве решений известен как корневой узел. Он учится разделять на основе значения атрибута. Он разбивает дерево рекурсивным способом, называемым рекурсивным разделением. Эта структура, похожая на блок-схему, поможет вам в принятии решений.
#
# ## GaussianNB -
#
# ### Наивные байесовские алгоритмы - это группа алгоритмов классификации с контролируемым машинным обучением, основанных на теореме Байеса. Это простой метод классификации, но обладающий высокой функциональностью. Они находят применение, когда размерность входных данных высока. Сложные задачи классификации также могут быть реализованы с помощью наивного байесовского классификатора.
#
# ## RandomForestClassifier -
#
# ### Случайный лес - это контролируемый алгоритм машинного обучения, используемый для решения задач классификации, а также регрессии. Это тип метода обучения в ансамбле, при котором из обучающего набора данных создается несколько деревьев решений, и большинство результатов из них рассматривается как
# ## Эти модели используются из-за хорошей работы на большом объеме данных и простоты их использования

# %% [markdown]
# # 2.4 Обучение

# %% [markdown]
# ## DecisionTreeClassifier

# %%
Model1 = tree.DecisionTreeClassifier(criterion='gini', random_state=0)
Model1.fit(x_train, y_train)
y_prob = Model1.predict_proba(x_test)[:, 1]
print(Model1.score(x_test,y_test))
# Out:
# 0.9976044027193266

# %%
print('DecisionTreeClassifier f1 = ' + str(f1_score(y_test, y_prob, average='macro')))
# Out:
# DecisionTreeClassifier f1 = 0.6615236632504532

# %%
print('DecisionTreeClassifier f1 = ' + str(classification_report(y_test, y_prob)))
# Out:
# DecisionTreeClassifier f1 =               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     27209
#            1       1.00      1.00      1.00     18509
#            2       0.00      0.00      0.00       617
#
#     accuracy                           0.98     46335
#    macro avg       0.66      0.67      0.66     46335
# weighted avg       0.97      0.98      0.98     46335
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## GaussianNB

# %%
Model2 = GaussianNB()
Model2.fit(x_train, y_train)
y_prob1 = Model2.predict_proba(x_test)[:, 1]
print(Model2.score(x_test, y_test))
# Out:
# 0.6604078989964389

# %%
print('GaussianNB f1 = ' + str(f1_score(y_test, y_prob1, average='macro')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 print('GaussianNB f1 = ' + str(f1_score(y_test, y_prob1, average='macro')))
#
# File D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1123, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     992 def f1_score(
#     993     y_true,
#     994     y_pred,
#    (...)
#    1000     zero_division="warn",
#    1001 ):
#    1002     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1003
#    1004     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#    1126         beta=1,
#    1127         labels=labels,
# ...

# %%
print('GaussianNB = ' + str(classification_report(y_test, y_prob1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 print('GaussianNB = ' + str(classification_report(y_test, y_prob1)))
#
# File D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:2110, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1998 def classification_report(
#    1999     y_true,
#    2000     y_pred,
#    (...)
#    2007     zero_division="warn",
#    2008 ):
#    2009     """Build a text report showing the main classification metrics.
#    2010
#    2011     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2107     <BLANKLINE>
#    2108     """
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2112     if labels is None:
#    2113         labels = unique_labels(y_true, y_pred)
#
# ...

# %% [markdown]
# ## RandomForestClassifier

# %%
# 3 запуска - 3 разных значения
model3 = RandomForestClassifier(random_state=0)
model3.fit(x_train, y_train)
y_prob2 = Model2.predict_proba(x_test)[:, 1]
print(model3.score(x_test,y_test))
# Out:
# 0.9982950253588

# %%
print('RandomForestClassifier f1 = ' + str(f1_score(y_test, y_prob2, average='macro')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 print('RandomForestClassifier f1 = ' + str(f1_score(y_test, y_prob2, average='macro')))
#
# File D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1123, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     992 def f1_score(
#     993     y_true,
#     994     y_pred,
#    (...)
#    1000     zero_division="warn",
#    1001 ):
#    1002     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1003
#    1004     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#    1126         beta=1,
#    1127         labels=labels,
# ...

# %% [markdown]
# ## MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
model4 = MultinomialNB().fit(x_train, y_train)
print(model4.score(x_test,y_test))
# Out:
# 0.6124527894680047

# %% [markdown]
# ## Выбираю модель с наибольшим score - RandomForestClassifier

# %% [markdown]
# ## Сохраняю модель

# %%
import pickle
pickle.dump(model3, open("classif.pkl", "wb"))

# %% [markdown]
# # 2.5 Feature Engineering

# %% [markdown]
# ## Добавление нового признака - коэф смертей среди новыx случаев

# %%
# Создание функции для рассчетов
def func(x):
    if x['new_cases'] == 0:
        return 0
    return x['new_deaths'] / x['new_cases']

# %%
# Добавление нового столбца
df['coef_d'] = df.apply(func, axis=1)

# %%
X = df.drop(['level', 'location', 'date'], axis=1)
y = df['level']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Обучаю RandomForestClassifier снова для проверки того, улучшится ли качество модели

# %%
model3 = RandomForestClassifier()
model3.fit(x_train, y_train)
print(model3.score(x_test,y_test))
# Out:
# 0.9992023071730993

# %% [markdown]
# ## Результаты выросли на буквально тысячные значения, так как значения и так близки к 1, однако это был лишь пример, и если нам и дальше надо увеличить точность, то мы могли бы добавить еще признаки или как-то изменить/усложнить формулу для создания более показательной характеристики

# %% [markdown]
# # 2.6 Подготовка отчета

# %% [markdown]
# ## 2.1 Произошло разбиение данных на трен и тест выборки

# %% [markdown]
# ## 2.2 Были визуализированы взаимосвязи между данными

# %% [markdown]
# ## 2.3 Были выбраны модели классификации

# %% [markdown]
# ## 2.4 Обучение моделей и выбор наилучшей

# %% [markdown]
# ## 2.5 Вариант дальнейшего увеличения точности модели
